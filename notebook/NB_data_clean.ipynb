# %%
from pymongo import MongoClient, ASCENDING, DESCENDING
import pandas as pd
import numpy as np
import dota2api

# %%
Mongo_clinet = MongoClient()
db = Mongo_clinet.dota2
coll = db.match_history

# %%
db.coll.count()
# Out:
# 25863

# %%
c = db.coll.find()

# %%
c.limit??

# %%
db.coll.find().limit

# %%
a = db.coll.find()

# %%
b = a.sort([('_id', DESCENDING)]).limit(1)

# %%
list(b)
# Out:
# [{u'_id': ObjectId('5672e87522f14a175fd1a41f'),
#   u'barracks_status_dire': 3,
#   u'barracks_status_radiant': 51,
#   u'cluster': 151,
#   u'duration': 3242,
#   u'engine': 1,
#   u'first_blood_time': 131,
#   u'game_mode': 1,
#   u'human_players': 10,
#   u'leagueid': 0,
#   u'lobby_type': 0,
#   u'match_id': 1928840724,
#   u'match_seq_num': 1704447656,
#   u'negative_votes': 0,
#   u'players': [{u'ability_upgrades': [{u'ability': 5004,
#       u'level': 1,
#       u'time': 218},
#      {u'ability': 5003, u'level': 2, u'time': 391},
#      {u'ability': 5003, u'level': 3, u'time': 468},
#      {u'ability': 5005, u'level': 4, u'time': 570},
#      {u'ability': 5005, u'level': 5, u'time': 685},
#      {u'ability': 5006, u'level': 6, u'time': 801},
#      {u'ability': 5003, u'level': 7, u'time': 913},
#      {u'ability': 5005, u'level': 8, u'time': 1011},
#      {u'ability': 5003, u'level': 9, u'time': 1128},
#      {u'ability': 5005, u'level': 10, u'time': 1247},
# ...

# %%
len(d)
# Out:
# 0

# %%
b.clone
# Out:
# <bound method Cursor.clone of <pymongo.cursor.Cursor object at 0x7f7f1dcb6190>>

# %%
import datetime

datetime.datetime.fromtimestamp(1447242221).strftime("%Y-%m-%d")
# Out:
# '2015-11-11'

# %%
#set up dota2api

api = dota2api.Initialise(logging=True)

# %%
api.get_match_history_by_seq_num()
# Out:
# {u'matches': [{u'barracks_status_dire': 0,
#    u'barracks_status_radiant': 0,
#    u'cluster': 0,
#    u'duration': 2408,
#    u'engine': 0,
#    u'first_blood_time': 0,
#    u'game_mode': 0,
#    u'human_players': 10,
#    u'leagueid': 0,
#    u'lobby_type': 0,
#    u'match_id': 496,
#    u'match_seq_num': 240,
#    u'negative_votes': 0,
#    u'players': [{u'account_id': 4294967295,
#      u'assists': 5,
#      u'deaths': 15,
#      u'denies': 0,
#      u'gold': 749,
#      u'gold_per_min': 172,
#      u'gold_spent': 0,
#      u'hero_damage': 0,
#      u'hero_healing': 0,
#      u'hero_id': 18,
#      u'item_0': 63,
#      u'item_1': 73,
#      u'item_2': 73,
#      u'item_3': 46,
#      u'item_4': 16,
#      u'item_5': 8,
#      u'kills': 3,
#      u'last_hits': 41,
#      u'leaver_status': 0,
#      u'level': 14,
#      u'player_slot': 0,
#      u'tower_damage': 0,
#      u'xp_per_min': 260},
#     {u'account_id': 54008249,
#      u'assists': 6,
#      u'deaths': 9,
# ...

# %%
def check_time(t):
    print datetime.datetime.fromtimestamp(t).strftime('%Y-%m-%d')

# %%
check_time(1302327641)
# Out:
# 2011-04-08

# %%
temp = api.get_match_history_by_seq_num(matches_requested=100)

# %%
len(temp['matches'])
# Out:
# 100

# %%
temp['matches'][-1]['start_time']
# Out:
# 1302327641

# %%
start_match_seq_num = 1704401237

# %%
add = api.get_match_history_by_seq_num(start_match_seq_num)

# %%
import json

# %%
# with open('match_history_temp.json', mode='w') as f:
#     json.dump([], f)

with open('match_history_temp.json', mode='w') as feedsjson:
#     feeds.append(temp)
    json.dump(add, feedsjson)

# %%
df = pd.read_json('match_history_temp.json')

# %%
df.head()
# Out:
#                                              matches  status
# 0  {u'tower_status_dire': 6, u'engine': 1, u'barr...       1
# 1  {u'tower_status_dire': 260, u'engine': 1, u'ba...       1
# 2  {u'tower_status_dire': 4, u'engine': 1, u'barr...       1
# 3  {u'tower_status_dire': 0, u'engine': 1, u'barr...       1
# 4  {u'tower_status_dire': 4, u'engine': 1, u'barr...       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 2 columns):
# matches    100 non-null object
# status     100 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
df['matches'][0]['match_seq_num']
# Out:
# 1704401237

# %%
seq_num = df.iloc[-1,:]['matches']['match_seq_num'] + 1

# %%
seq_num
# Out:
# 1704401399

# %%
add1 = api.get_match_history_by_seq_num(start_at_match_seq_num=seq_num)

# %%
with open('match_history_temp.json', mode='w') as feedsjson:
#     feeds.append(temp)
    json.dump(add1, feedsjson)

# %%
df_1 = pd.read_json('match_history_temp.json')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 2 columns):
# matches    100 non-null object
# status     100 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
df_1['matches'][0]['match_seq_num']
# Out:
# 1704401404

# %%
(df_1['matches']==start_match_seq_num).any()
# Out:
# False

# %%
with open('match_history_temp1.json', 'w') as outfile:
    json.dump(add1, outfile)

# %%
pd.read_json('match_history_temp1.json')['matches'][0]['match_seq_num']
# Out:
# 1704401404

# %%
with open('match_history_temp.json', 'a') as f:
    json.dump(add1, f)

# %%
with open('match_history.json') as f:
    #print sum(1 for _ in f)
    z = f.readline()
    x = json.loads(f.readline())
    
    for line in f:
        y = line

# %%
type(y)
# Out:
# str

# %%
type(z)
# Out:
# str

# %%
df_x = pd.DataFrame.from_dict(x)

# %%
df_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 2 columns):
# matches    100 non-null object
# status     100 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB
