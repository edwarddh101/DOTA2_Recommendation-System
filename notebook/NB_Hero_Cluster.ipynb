# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
pwd
# Out:
# u'/home/hao/Repos/DSI/DOTA2_Recommendation-System/notebook'

# %%
cd ..
# Out:
# /home/hao/Repos/DSI/DOTA2_Recommendation-System

# %%
df = pd.read_csv('file/hero_attributes', sep='t',index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 110
# Data columns (total 23 columns):
# HERO        110 non-null object
# ATT         110 non-null object
# STR         110 non-null int64
# STR+        110 non-null float64
# AGI         110 non-null int64
# AGI+        110 non-null float64
# INT         110 non-null int64
# INT+        110 non-null float64
# T+          110 non-null float64
# LVL25       110 non-null float64
# MOV         110 non-null int64
# AR          110 non-null float64
# DMG(MIN)    110 non-null int64
# DMG(MAX)    110 non-null int64
# RNG         110 non-null int64
# BAT         110 non-null float64
# ATKPT       110 non-null float64
# ATKBS       110 non-null float64
# VIS-D       110 non-null object
# VIS-N       110 non-null object
# TURN        110 non-null float64
# COLL        110 non-null int64
# HP/S        110 non-null float64
# dtypes: float64(11), int64(8), object(4)
# memory usage: 20.6+ KB

# %%
df.head()
# Out:
#                  HERO           ATT  STR  STR+  AGI  AGI+  INT  INT+   T+  \
# 0             Abaddon      Strength   23   2.7   17   1.5   21   2.0  6.2
# 1           Alchemist      Strength   25   1.8   11   1.2   25   1.8  4.8
# 2  Ancient Apparition  Intelligence   18   1.4   20   2.2   25   2.6  6.2
# 3           Anti-Mage       Agility   22   1.2   22   2.8   15   1.8  5.8
# 5                 Axe      Strength   25   2.5   20   2.2   18   1.6  6.3
#
#    LVL25  ...   DMG(MAX)  RNG   BAT  ATKPT  ATKBS  VIS-D  VIS-N  TURN COLL  \
# 0  216.0  ...         65  128  1.70   0.56   0.41  1,800    800   0.6   24
# 1  181.0  ...         58  128  1.70   0.35   0.65  1,800    800   0.6   24
# 2  218.0  ...         54  600  1.70   0.45   0.30  1,800    800   0.6   24
# 3  204.0  ...         53  128  1.45   0.30   0.60  1,800    800   0.5   24
# 5  220.5  ...         53  128  1.70   0.50   0.50  1,800    800   0.6   24
#
#    HP/S
# 0  0.25
# 1  0.25
# 2  0.25
# 3  0.25
# 5  3.00
#
# ...

# %%
df.describe().T
# Out:
#           count        mean         std     min       25%     50%       75%  \
# STR         110   19.909091    3.263772   14.00   17.0000   19.50   22.7500
# STR+        110    2.163636    0.533764    1.00    1.8000    2.10    2.5000
# AGI         110   17.909091    4.510020    9.00   15.0000   18.00   21.0000
# AGI+        110    1.953636    0.618770    0.80    1.5000    1.90    2.2875
# INT         110   19.363636    4.087859   13.00   16.0000   18.00   22.0000
# INT+        110    2.144545    0.634929    1.00    1.6625    2.00    2.6000
# T+          110    6.261818    0.550060    4.80    6.0000    6.20    6.6000
# LVL25       110  213.727273   14.536357  181.00  205.0000  213.75  221.0000
# MOV         110  300.727273   12.169227  270.00  290.0000  300.00  310.0000
# AR          110    2.698182    1.729985   -0.46    1.2700    2.40    3.7500
# DMG(MIN)    110   47.527273    7.626257   29.00   43.0000   46.50   51.0000
# ...

# %%
df.head(1).T
# Out:
#                  0
# HERO       Abaddon
# ATT       Strength
# STR             23
# STR+           2.7
# AGI             17
# AGI+           1.5
# INT             21
# INT+             2
# T+             6.2
# LVL25          216
# MOV            310
# AR            1.38
# DMG(MIN)        55
# DMG(MAX)        65
# RNG            128
# BAT            1.7
# ATKPT         0.56
# ATKBS         0.41
# VIS-D        1,800
# VIS-N          800
# TURN           0.6
# COLL            24
# HP/S          0.25

# %%
df_hero = df.copy(deep=True)

# %%
df_hero.drop(['HERO', 'ATT'], axis=1, inplace=True)

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 110
# Data columns (total 21 columns):
# STR         110 non-null int64
# STR+        110 non-null float64
# AGI         110 non-null int64
# AGI+        110 non-null float64
# INT         110 non-null int64
# INT+        110 non-null float64
# T+          110 non-null float64
# LVL25       110 non-null float64
# MOV         110 non-null int64
# AR          110 non-null float64
# DMG(MIN)    110 non-null int64
# DMG(MAX)    110 non-null int64
# RNG         110 non-null int64
# BAT         110 non-null float64
# ATKPT       110 non-null float64
# ATKBS       110 non-null float64
# VIS-D       110 non-null object
# VIS-N       110 non-null object
# TURN        110 non-null float64
# COLL        110 non-null int64
# HP/S        110 non-null float64
# dtypes: float64(11), int64(8), object(2)
# memory usage: 18.9+ KB

# %%
df_hero[['VIS-D', 'VIS-N']] = df_hero[['VIS-D', 'VIS-N']].applymap(lambda x: int(x.replace(',', '')))

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
df_hero = df_hero.apply(lambda x: min_max_scaler.fit_transform(x), axis=1)

# %% [markdown]
# ### Kmeans clustering without PCA

# %%
from sklearn.cluster import KMeans

# %%
Kmeans
